# %%
import os, sys, glob
print("python:", sys.executable)
print("cwd:", os.getcwd())
print("/jars exists:", os.path.exists("/jars"))
print("/jars glob:", glob.glob("/jars/*.jar"))
# Out:
# python: /usr/local/bin/python
# cwd: /home/jovyan/work
# /jars exists: True
# /jars glob: ['/jars/aws-java-sdk-bundle-1.12.262.jar', '/jars/hadoop-aws-3.3.4.jar', '/jars/postgresql-42.7.4.jar']
